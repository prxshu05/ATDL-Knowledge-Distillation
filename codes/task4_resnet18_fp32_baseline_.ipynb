# %% [markdown]
# # ATDL Assignment 1 — Task 4 (baseline half): FP32 ResNet18, no KD
#
# **Why this notebook exists:** the assignment requires a three-way comparison table — teacher (ResNet34, FP32) vs. FP32 ResNet18 baseline (no KD, no quantization) vs. ternary ResNet18 (KD+QAT). This notebook produces the middle column. Its checkpoint will *also* be used to warm-start the ternary student's latent weights in Task 3 (rather than random init), which tends to give QAT a much more stable starting point than training a ternary network from scratch.
#
# **Identical to the Task 1 notebook in every way that matters for a fair comparison:**
# - Same `SEED = 42` → identical 45k/5k/10k data split.
# - Same augmentation, same "bag of tricks" (Cutout, label smoothing, no weight decay on BN/bias, zero-init residual, EMA).
# - Same warmup + `ReduceLROnPlateau` + early-stopping schedule.
#
# **Only difference:** `[2, 2, 2, 2]` BasicBlocks (ResNet18) instead of `[3, 4, 6, 3]` (ResNet34), and **no distillation** — this is trained purely against the true labels, so it's the fair "what if we just used a smaller FP32 network" baseline.
#
# **Before running:** Runtime > Change runtime type > T4 GPU.

# %%
import os, sys

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=False)
    DRIVE_DIR = "/content/drive/MyDrive/atdl"
    os.makedirs(DRIVE_DIR, exist_ok=True)
    print(f"Google Drive mounted. Saving checkpoints/plots to: {DRIVE_DIR}")
else:
    DRIVE_DIR = "."
    print("Not running in Colab -- saving to the local working directory.")

CKPT_PATH = os.path.join(DRIVE_DIR, "resnet18_cifar10_fp32_baseline_best.pth")
CURVE_PATH = os.path.join(DRIVE_DIR, "resnet18_baseline_training_curves.png")
TEACHER_CKPT = os.path.join(DRIVE_DIR, "resnet34_cifar10_teacher_best.pth")

if not os.path.exists(TEACHER_CKPT):
    print(f"NOTE: teacher checkpoint not found yet at {TEACHER_CKPT} -- that's fine, "
          "this notebook doesn't need it. Just confirming Task 1 ran, since Task 3 will need it next.")
else:
    print(f"Found teacher checkpoint at {TEACHER_CKPT} -- Task 1 is done.")
# Out:
# Mounted at /content/drive
# Google Drive mounted. Saving checkpoints/plots to: /content/drive/MyDrive/atdl
# Found teacher checkpoint at /content/drive/MyDrive/atdl/resnet34_cifar10_teacher_best.pth -- Task 1 is done.

# %% [markdown]
# ## Reproducibility
#
# Same `SEED` as the Task 1 notebook. This is what guarantees this baseline sees the *exact same* 45k/5k/10k partition as the teacher and (later) the student — without this, the three-way comparison table wouldn't be apples-to-apples.

# %%
import copy
import time
import random
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Subset
from torch.amp import autocast, GradScaler
import matplotlib.pyplot as plt

SEED = 42

def set_seed(seed=SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed()
torch.backends.cudnn.benchmark = True

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")
if DEVICE.type != "cuda":
    print("WARNING: no GPU detected. Go to Runtime > Change runtime type > T4 GPU.")
# Out:
# Using device: cuda

# %% [markdown]
# ## Model: CIFAR-adapted ResNet18
#
# Identical `BasicBlock`/stem to the Task 1 teacher -- only the per-stage block counts differ (`[2,2,2,2]` vs `[3,4,6,3]`), which is the textbook ResNet18-vs-ResNet34 distinction from He et al. Keeping the block and stem code byte-for-byte identical to Task 1 (not just architecturally equivalent) matters here, since the ternary version of this exact class is what Task 2/3 will build on top of.

# %%
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super().__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride,
                                padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1,
                                padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion * planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion * planes, kernel_size=1,
                          stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * planes),
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = out + self.shortcut(x)
        return F.relu(out)


class ResNetCIFAR(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super().__init__()
        self.in_planes = 64
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        self.fc = nn.Linear(512 * block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for s in strides:
            layers.append(block(self.in_planes, planes, s))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = torch.flatten(out, 1)
        return self.fc(out)


def ResNet18(num_classes=10):
    return ResNetCIFAR(BasicBlock, [2, 2, 2, 2], num_classes)


def zero_init_residual(model):
    for m in model.modules():
        if isinstance(m, BasicBlock):
            nn.init.zeros_(m.bn2.weight)

# %% [markdown]
# ## Data pipeline
#
# Byte-for-byte identical to the Task 1 notebook — same transforms, same `SEED`-based 45k/5k/10k split, same `clean_train_loader` for an honest (non-augmented) train accuracy at the end.

# %%
CIFAR_MEAN = (0.4914, 0.4822, 0.4465)
CIFAR_STD = (0.2470, 0.2435, 0.2616)


class Cutout:
    def __init__(self, n_holes=1, length=16):
        self.n_holes = n_holes
        self.length = length

    def __call__(self, img):
        h, w = img.size(1), img.size(2)
        mask = torch.ones((h, w), dtype=img.dtype)
        for _ in range(self.n_holes):
            y = random.randint(0, h - 1)
            x = random.randint(0, w - 1)
            y1, y2 = max(y - self.length // 2, 0), min(y + self.length // 2, h)
            x1, x2 = max(x - self.length // 2, 0), min(x + self.length // 2, w)
            mask[y1:y2, x1:x2] = 0.0
        return img * mask.unsqueeze(0)


train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
    Cutout(n_holes=1, length=16),
])

eval_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(CIFAR_MEAN, CIFAR_STD),
])


def get_dataloaders(data_dir="./data", batch_size=128, num_workers=2, n_val=5000):
    full_train_aug = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=train_transform)
    full_train_plain = torchvision.datasets.CIFAR10(
        root=data_dir, train=True, download=True, transform=eval_transform)
    test_set = torchvision.datasets.CIFAR10(
        root=data_dir, train=False, download=True, transform=eval_transform)

    n_total = len(full_train_aug)
    n_train = n_total - n_val

    g = torch.Generator().manual_seed(SEED)
    perm = torch.randperm(n_total, generator=g).tolist()
    train_idx, val_idx = perm[:n_train], perm[n_train:]

    train_set = Subset(full_train_aug, train_idx)
    val_set = Subset(full_train_plain, val_idx)
    clean_train_set = Subset(full_train_plain, train_idx)

    train_loader = torch.utils.data.DataLoader(
        train_set, batch_size=batch_size, shuffle=True,
        num_workers=num_workers, pin_memory=True, drop_last=True)
    val_loader = torch.utils.data.DataLoader(
        val_set, batch_size=256, shuffle=False,
        num_workers=num_workers, pin_memory=True)
    test_loader = torch.utils.data.DataLoader(
        test_set, batch_size=256, shuffle=False,
        num_workers=num_workers, pin_memory=True)
    clean_train_loader = torch.utils.data.DataLoader(
        clean_train_set, batch_size=256, shuffle=False,
        num_workers=num_workers, pin_memory=True)

    return train_loader, val_loader, test_loader, clean_train_loader

# %% [markdown]
# ## EMA and no-decay parameter groups
#
# Same as Task 1 -- kept identical so any accuracy difference you observe later is attributable to model capacity (ResNet18 vs ResNet34) and architecture alone, not to a training-recipe mismatch.

# %%
class ModelEMA:
    def __init__(self, model, decay=0.9998):
        self.decay = decay
        self.ema = copy.deepcopy(model).eval()
        for p in self.ema.parameters():
            p.requires_grad_(False)

    @torch.no_grad()
    def update(self, model):
        msd = model.state_dict()
        for k, v_ema in self.ema.state_dict().items():
            v = msd[k]
            if v.dtype.is_floating_point:
                v_ema.mul_(self.decay).add_(v.detach(), alpha=1 - self.decay)
            else:
                v_ema.copy_(v)


def get_param_groups(model, weight_decay):
    decay, no_decay = [], []
    for name, param in model.named_parameters():
        if not param.requires_grad:
            continue
        if param.ndim <= 1 or name.endswith(".bias"):
            no_decay.append(param)
        else:
            decay.append(param)
    return [
        {"params": decay, "weight_decay": weight_decay},
        {"params": no_decay, "weight_decay": 0.0},
    ]

# %% [markdown]
# ## Train / eval loops
#
# Same non-deprecated `torch.amp` API as Task 1.

# %%
def evaluate(model, loader, criterion):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(DEVICE, non_blocking=True), y.to(DEVICE, non_blocking=True)
            out = model(x)
            loss = criterion(out, y)
            total_loss += loss.item() * x.size(0)
            correct += (out.argmax(1) == y).sum().item()
            total += x.size(0)
    return total_loss / total, 100.0 * correct / total


def train_one_epoch(model, loader, criterion, optimizer, scaler, ema):
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    for x, y in loader:
        x, y = x.to(DEVICE, non_blocking=True), y.to(DEVICE, non_blocking=True)
        optimizer.zero_grad(set_to_none=True)

        with autocast(device_type=DEVICE.type, enabled=(DEVICE.type == "cuda")):
            out = model(x)
            loss = criterion(out, y)

        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        ema.update(model)

        total_loss += loss.item() * x.size(0)
        correct += (out.argmax(1) == y).sum().item()
        total += x.size(0)
    return total_loss / total, 100.0 * correct / total

# %% [markdown]
# ## Training config and main loop
#
# Same warmup + `ReduceLROnPlateau` + early-stopping recipe as Task 1, same epoch ceiling (200) with early stopping deciding the real duration. The honest train/test gap (clean, non-augmented train accuracy vs. test accuracy) is computed the same way as the Task 1 fix.

# %%
def main():
    EPOCHS = 200                # CEILING -- early stopping decides real duration
    WARMUP_EPOCHS = 5
    BATCH_SIZE = 128
    LR = 0.1
    MOMENTUM = 0.9
    WEIGHT_DECAY = 5e-4
    LABEL_SMOOTHING = 0.1
    EMA_DECAY = 0.9998
    LR_PATIENCE = 8
    LR_FACTOR = 0.5
    MIN_LR = 1e-4
    EARLY_STOP_PATIENCE = 20
    MIN_DELTA = 0.05

    train_loader, val_loader, test_loader, clean_train_loader = get_dataloaders(batch_size=BATCH_SIZE)

    model = ResNet18(num_classes=10).to(DEVICE)
    zero_init_residual(model)

    criterion = nn.CrossEntropyLoss(label_smoothing=LABEL_SMOOTHING)
    optimizer = optim.SGD(get_param_groups(model, WEIGHT_DECAY), lr=LR,
                           momentum=MOMENTUM, nesterov=True)

    warmup_sched = optim.lr_scheduler.LinearLR(optimizer, start_factor=0.01,
                                                total_iters=WARMUP_EPOCHS)
    plateau_sched = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="max", factor=LR_FACTOR, patience=LR_PATIENCE, min_lr=MIN_LR)

    scaler = GradScaler(device=DEVICE.type, enabled=(DEVICE.type == "cuda"))
    ema = ModelEMA(model, decay=EMA_DECAY)

    history = {k: [] for k in [
        "train_loss", "train_acc",
        "val_acc_raw", "val_acc_ema",
        "test_acc_raw", "test_acc_ema", "lr",
    ]}
    best_val_acc, best_source = 0.0, None
    epochs_without_improvement = 0

    for epoch in range(1, EPOCHS + 1):
        t0 = time.time()
        train_loss, train_acc = train_one_epoch(model, train_loader, criterion, optimizer, scaler, ema)

        val_acc_raw = evaluate(model, val_loader, criterion)[1]
        val_acc_ema = evaluate(ema.ema, val_loader, criterion)[1]
        test_acc_raw = evaluate(model, test_loader, criterion)[1]
        test_acc_ema = evaluate(ema.ema, test_loader, criterion)[1]

        if epoch <= WARMUP_EPOCHS:
            warmup_sched.step()
        else:
            plateau_sched.step(val_acc_ema)

        cur_lr = optimizer.param_groups[0]["lr"]
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["val_acc_raw"].append(val_acc_raw)
        history["val_acc_ema"].append(val_acc_ema)
        history["test_acc_raw"].append(test_acc_raw)
        history["test_acc_ema"].append(test_acc_ema)
        history["lr"].append(cur_lr)

        improved = False
        for source, v_acc, sd in [("raw", val_acc_raw, model.state_dict()),
                                   ("ema", val_acc_ema, ema.ema.state_dict())]:
            if v_acc > best_val_acc + MIN_DELTA:
                best_val_acc = v_acc
                best_source = source
                improved = True
                torch.save({
                    "epoch": epoch,
                    "model_state_dict": copy.deepcopy(sd),
                    "val_acc": v_acc,
                    "source": source,
                    "seed": SEED,
                    "arch": "resnet18_cifar_fp32_baseline",
                }, CKPT_PATH)

        epochs_without_improvement = 0 if improved else epochs_without_improvement + 1

        dt = time.time() - t0
        print(f"Epoch {epoch:3d}/{EPOCHS} | lr {cur_lr:.5f} | "
              f"train {train_loss:.4f}/{train_acc:.2f}% | "
              f"val raw/ema {val_acc_raw:.2f}%/{val_acc_ema:.2f}% | "
              f"test raw/ema {test_acc_raw:.2f}%/{test_acc_ema:.2f}% | "
              f"best_val {best_val_acc:.2f}% ({best_source}) | "
              f"no_improve {epochs_without_improvement}/{EARLY_STOP_PATIENCE} | {dt:.1f}s")

        if epochs_without_improvement >= EARLY_STOP_PATIENCE:
            print(f"\nEarly stopping at epoch {epoch}: no val-accuracy improvement "
                  f"(> {MIN_DELTA} pts) for {EARLY_STOP_PATIENCE} epochs. "
                  f"Best: {best_val_acc:.2f}% ({best_source}) at epoch "
                  f"{epoch - epochs_without_improvement}.")
            break

    best_ckpt = torch.load(CKPT_PATH, map_location=DEVICE)
    eval_model = ResNet18(num_classes=10).to(DEVICE)
    eval_model.load_state_dict(best_ckpt["model_state_dict"])

    _, final_test_acc = evaluate(eval_model, test_loader, criterion)
    _, honest_train_acc = evaluate(eval_model, clean_train_loader, criterion)

    print(f"\nBest checkpoint: epoch {best_ckpt['epoch']}, source={best_ckpt['source']}, "
          f"val_acc {best_ckpt['val_acc']:.2f}%")
    print(f"Final test accuracy: {final_test_acc:.2f}%")
    print(f"Honest clean train accuracy (same 45k images, no augmentation): {honest_train_acc:.2f}%")
    print(f"Honest train/test gap: {honest_train_acc - final_test_acc:.2f} points")
    print(f"Checkpoint saved to: {CKPT_PATH}")

    return history

# %%
history = main()
# Out:
# 100%|██████████| 170M/170M [00:32<00:00, 5.23MB/s]
# Epoch   1/200 | lr 0.02080 | train 2.1639/22.25% | val raw/ema 27.42%/9.24% | test raw/ema 27.73%/9.90% | best_val 27.42% (raw) | no_improve 0/20 | 51.3s
# Epoch   2/200 | lr 0.04060 | train 1.9165/32.51% | val raw/ema 42.06%/9.42% | test raw/ema 41.66%/9.93% | best_val 42.06% (raw) | no_improve 0/20 | 35.6s
# Epoch   3/200 | lr 0.06040 | train 1.6763/45.29% | val raw/ema 51.00%/9.42% | test raw/ema 51.05%/10.00% | best_val 51.00% (raw) | no_improve 0/20 | 36.8s
# Epoch   4/200 | lr 0.08020 | train 1.5066/54.25% | val raw/ema 59.06%/9.42% | test raw/ema 58.55%/10.00% | best_val 59.06% (raw) | no_improve 0/20 | 37.9s
# Epoch   5/200 | lr 0.10000 | train 1.3955/59.89% | val raw/ema 66.08%/10.22% | test raw/ema 65.63%/10.86% | best_val 66.08% (raw) | no_improve 0/20 | 36.8s
# Epoch   6/200 | lr 0.10000 | train 1.3112/63.60% | val raw/ema 64.82%/12.58% | test raw/ema 65.48%/13.17% | best_val 66.08% (raw) | no_improve 1/20 | 37.0s
# Epoch   7/200 | lr 0.10000 | train 1.2133/68.51% | val raw/ema 74.40%/12.74% | test raw/ema 74.17%/13.44% | best_val 74.40% (raw) | no_improve 0/20 | 35.8s
# Epoch   8/200 | lr 0.10000 | train 1.1525/71.06% | val raw/ema 71.66%/12.24% | test raw/ema 71.97%/13.37% | best_val 74.40% (raw) | no_improve 1/20 | 38.1s
# Epoch   9/200 | lr 0.10000 | train 1.1087/73.33% | val raw/ema 75.34%/12.98% | test raw/ema 75.86%/13.95% | best_val 75.34% (raw) | no_improve 0/20 | 38.0s
# Epoch  10/200 | lr 0.10000 | train 1.0688/75.03% | val raw/ema 77.44%/13.02% | test raw/ema 77.09%/14.13% | best_val 77.44% (raw) | no_improve 0/20 | 37.9s
# Epoch  11/200 | lr 0.10000 | train 1.0474/75.92% | val raw/ema 76.22%/13.16% | test raw/ema 76.04%/14.22% | best_val 77.44% (raw) | no_improve 1/20 | 38.5s
# Epoch  12/200 | lr 0.10000 | train 1.0195/77.21% | val raw/ema 75.28%/13.38% | test raw/ema 75.88%/14.27% | best_val 77.44% (raw) | no_improve 2/20 | 35.4s
# Epoch  13/200 | lr 0.10000 | train 1.0055/77.64% | val raw/ema 76.70%/13.68% | test raw/ema 77.31%/14.58% | best_val 77.44% (raw) | no_improve 3/20 | 37.3s
# Epoch  14/200 | lr 0.10000 | train 0.9888/78.58% | val raw/ema 79.16%/14.20% | test raw/ema 78.98%/15.26% | best_val 79.16% (raw) | no_improve 0/20 | 36.1s
# Epoch  15/200 | lr 0.10000 | train 0.9722/79.26% | val raw/ema 81.64%/14.90% | test raw/ema 81.52%/15.70% | best_val 81.64% (raw) | no_improve 0/20 | 37.9s
# Epoch  16/200 | lr 0.10000 | train 0.9599/79.96% | val raw/ema 79.06%/15.12% | test raw/ema 78.26%/16.04% | best_val 81.64% (raw) | no_improve 1/20 | 36.4s
# Epoch  17/200 | lr 0.10000 | train 0.9493/80.39% | val raw/ema 81.78%/15.38% | test raw/ema 82.03%/16.24% | best_val 81.78% (raw) | no_improve 0/20 | 35.7s
# Epoch  18/200 | lr 0.10000 | train 0.9406/80.62% | val raw/ema 82.08%/15.52% | test raw/ema 81.62%/16.35% | best_val 82.08% (raw) | no_improve 0/20 | 36.0s
# Epoch  19/200 | lr 0.10000 | train 0.9331/80.93% | val raw/ema 82.44%/15.72% | test raw/ema 81.64%/16.48% | best_val 82.44% (raw) | no_improve 0/20 | 37.1s
# Epoch  20/200 | lr 0.10000 | train 0.9239/81.28% | val raw/ema 84.76%/15.82% | test raw/ema 84.64%/16.64% | best_val 84.76% (raw) | no_improve 0/20 | 35.9s
# Epoch  21/200 | lr 0.10000 | train 0.9183/81.58% | val raw/ema 83.56%/15.96% | test raw/ema 83.46%/16.83% | best_val 84.76% (raw) | no_improve 1/20 | 36.8s
# Epoch  22/200 | lr 0.10000 | train 0.9136/81.97% | val raw/ema 84.60%/16.10% | test raw/ema 83.65%/17.17% | best_val 84.76% (raw) | no_improve 2/20 | 34.4s
# Epoch  23/200 | lr 0.10000 | train 0.9095/82.09% | val raw/ema 82.48%/16.58% | test raw/ema 81.95%/17.49% | best_val 84.76% (raw) | no_improve 3/20 | 36.1s
# Epoch  24/200 | lr 0.10000 | train 0.9002/82.61% | val raw/ema 84.66%/16.88% | test raw/ema 84.87%/17.88% | best_val 84.76% (raw) | no_improve 4/20 | 34.4s
# Epoch  25/200 | lr 0.10000 | train 0.8996/82.59% | val raw/ema 84.86%/17.46% | test raw/ema 84.30%/18.27% | best_val 84.86% (raw) | no_improve 0/20 | 35.9s
# Epoch  26/200 | lr 0.10000 | train 0.8936/82.84% | val raw/ema 85.96%/18.26% | test raw/ema 85.78%/18.96% | best_val 85.96% (raw) | no_improve 0/20 | 35.5s
# Epoch  27/200 | lr 0.10000 | train 0.8899/82.97% | val raw/ema 84.78%/19.52% | test raw/ema 84.06%/20.16% | best_val 85.96% (raw) | no_improve 1/20 | 36.4s
# Epoch  28/200 | lr 0.10000 | train 0.8838/83.16% | val raw/ema 84.76%/21.32% | test raw/ema 84.77%/21.70% | best_val 85.96% (raw) | no_improve 2/20 | 34.3s
# Epoch  29/200 | lr 0.10000 | train 0.8804/83.42% | val raw/ema 83.76%/23.50% | test raw/ema 83.31%/23.77% | best_val 85.96% (raw) | no_improve 3/20 | 34.7s
# Epoch  30/200 | lr 0.10000 | train 0.8787/83.38% | val raw/ema 83.58%/25.92% | test raw/ema 82.84%/26.35% | best_val 85.96% (raw) | no_improve 4/20 | 35.2s
# Epoch  31/200 | lr 0.10000 | train 0.8730/83.83% | val raw/ema 86.12%/29.10% | test raw/ema 86.29%/29.50% | best_val 86.12% (raw) | no_improve 0/20 | 34.3s
# Epoch  32/200 | lr 0.10000 | train 0.8732/83.59% | val raw/ema 81.86%/33.72% | test raw/ema 81.11%/33.63% | best_val 86.12% (raw) | no_improve 1/20 | 36.5s
# Epoch  33/200 | lr 0.10000 | train 0.8693/83.75% | val raw/ema 83.46%/38.60% | test raw/ema 83.76%/38.12% | best_val 86.12% (raw) | no_improve 2/20 | 34.0s
# Epoch  34/200 | lr 0.10000 | train 0.8669/84.08% | val raw/ema 84.64%/44.08% | test raw/ema 83.99%/43.63% | best_val 86.12% (raw) | no_improve 3/20 | 34.5s
# Epoch  35/200 | lr 0.10000 | train 0.8616/84.08% | val raw/ema 85.72%/48.86% | test raw/ema 85.34%/49.10% | best_val 86.12% (raw) | no_improve 4/20 | 34.4s
# Epoch  36/200 | lr 0.10000 | train 0.8615/84.16% | val raw/ema 83.72%/54.18% | test raw/ema 83.67%/54.32% | best_val 86.12% (raw) | no_improve 5/20 | 34.2s
# Epoch  37/200 | lr 0.10000 | train 0.8577/84.31% | val raw/ema 85.34%/59.08% | test raw/ema 84.98%/59.22% | best_val 86.12% (raw) | no_improve 6/20 | 35.2s
# Epoch  38/200 | lr 0.10000 | train 0.8573/84.23% | val raw/ema 85.84%/63.26% | test raw/ema 85.61%/63.73% | best_val 86.12% (raw) | no_improve 7/20 | 33.5s
# Epoch  39/200 | lr 0.10000 | train 0.8632/84.04% | val raw/ema 83.66%/67.26% | test raw/ema 83.78%/67.69% | best_val 86.12% (raw) | no_improve 8/20 | 33.8s
# Epoch  40/200 | lr 0.10000 | train 0.8532/84.45% | val raw/ema 85.86%/70.64% | test raw/ema 85.71%/70.68% | best_val 86.12% (raw) | no_improve 9/20 | 34.2s
# Epoch  41/200 | lr 0.10000 | train 0.8500/84.88% | val raw/ema 86.94%/73.60% | test raw/ema 87.33%/73.38% | best_val 86.94% (raw) | no_improve 0/20 | 33.3s
# Epoch  42/200 | lr 0.10000 | train 0.8469/84.91% | val raw/ema 87.38%/75.90% | test raw/ema 87.20%/75.68% | best_val 87.38% (raw) | no_improve 0/20 | 35.9s
# Epoch  43/200 | lr 0.10000 | train 0.8465/84.76% | val raw/ema 85.40%/77.92% | test raw/ema 85.32%/77.83% | best_val 87.38% (raw) | no_improve 1/20 | 34.5s
# Epoch  44/200 | lr 0.10000 | train 0.8509/84.68% | val raw/ema 87.62%/79.60% | test raw/ema 86.84%/79.84% | best_val 87.62% (raw) | no_improve 0/20 | 33.8s
# Epoch  45/200 | lr 0.10000 | train 0.8451/85.00% | val raw/ema 83.86%/81.18% | test raw/ema 84.76%/81.26% | best_val 87.62% (raw) | no_improve 1/20 | 35.4s
# Epoch  46/200 | lr 0.10000 | train 0.8474/84.88% | val raw/ema 87.66%/82.74% | test raw/ema 87.12%/82.53% | best_val 87.62% (raw) | no_improve 2/20 | 32.9s
# Epoch  47/200 | lr 0.10000 | train 0.8403/85.04% | val raw/ema 81.06%/83.58% | test raw/ema 81.12%/83.52% | best_val 87.62% (raw) | no_improve 3/20 | 34.2s
# Epoch  48/200 | lr 0.10000 | train 0.8419/85.16% | val raw/ema 87.40%/84.42% | test raw/ema 86.92%/84.63% | best_val 87.62% (raw) | no_improve 4/20 | 33.8s
# Epoch  49/200 | lr 0.10000 | train 0.8361/85.25% | val raw/ema 85.60%/85.08% | test raw/ema 85.10%/85.34% | best_val 87.62% (raw) | no_improve 5/20 | 33.4s
# Epoch  50/200 | lr 0.10000 | train 0.8422/85.15% | val raw/ema 87.88%/86.02% | test raw/ema 87.40%/86.09% | best_val 87.88% (raw) | no_improve 0/20 | 34.1s
# Epoch  51/200 | lr 0.10000 | train 0.8373/85.04% | val raw/ema 85.66%/86.60% | test raw/ema 85.20%/86.61% | best_val 87.88% (raw) | no_improve 1/20 | 34.0s
# Epoch  52/200 | lr 0.10000 | train 0.8364/85.37% | val raw/ema 88.56%/87.20% | test raw/ema 87.75%/86.99% | best_val 88.56% (raw) | no_improve 0/20 | 33.5s
# Epoch  53/200 | lr 0.10000 | train 0.8317/85.43% | val raw/ema 85.04%/87.52% | test raw/ema 84.57%/87.33% | best_val 88.56% (raw) | no_improve 1/20 | 35.8s
# Epoch  54/200 | lr 0.10000 | train 0.8353/85.29% | val raw/ema 86.46%/87.90% | test raw/ema 86.29%/87.77% | best_val 88.56% (raw) | no_improve 2/20 | 33.4s
# Epoch  55/200 | lr 0.10000 | train 0.8306/85.49% | val raw/ema 86.82%/88.30% | test raw/ema 86.87%/88.11% | best_val 88.56% (raw) | no_improve 3/20 | 33.8s
# Epoch  56/200 | lr 0.10000 | train 0.8293/85.68% | val raw/ema 86.74%/88.54% | test raw/ema 87.01%/88.40% | best_val 88.56% (raw) | no_improve 4/20 | 33.9s
# Epoch  57/200 | lr 0.10000 | train 0.8290/85.67% | val raw/ema 86.18%/88.78% | test raw/ema 85.73%/88.61% | best_val 88.78% (ema) | no_improve 0/20 | 33.2s
# Epoch  58/200 | lr 0.10000 | train 0.8291/85.58% | val raw/ema 86.20%/89.08% | test raw/ema 85.33%/88.93% | best_val 89.08% (ema) | no_improve 0/20 | 35.0s
# Epoch  59/200 | lr 0.10000 | train 0.8337/85.53% | val raw/ema 86.70%/89.38% | test raw/ema 86.46%/89.10% | best_val 89.38% (ema) | no_improve 0/20 | 34.0s
# Epoch  60/200 | lr 0.10000 | train 0.8282/85.51% | val raw/ema 86.92%/89.64% | test raw/ema 87.06%/89.42% | best_val 89.64% (ema) | no_improve 0/20 | 33.9s
# Epoch  61/200 | lr 0.10000 | train 0.8276/85.72% | val raw/ema 87.86%/89.90% | test raw/ema 87.97%/89.66% | best_val 89.90% (ema) | no_improve 0/20 | 35.4s
# Epoch  62/200 | lr 0.10000 | train 0.8201/85.96% | val raw/ema 88.74%/90.04% | test raw/ema 87.93%/89.97% | best_val 90.04% (ema) | no_improve 0/20 | 34.0s
# Epoch  63/200 | lr 0.10000 | train 0.8267/85.80% | val raw/ema 87.34%/90.40% | test raw/ema 87.35%/90.13% | best_val 90.40% (ema) | no_improve 0/20 | 35.5s
# Epoch  64/200 | lr 0.10000 | train 0.8248/85.87% | val raw/ema 86.30%/90.54% | test raw/ema 86.04%/90.26% | best_val 90.54% (ema) | no_improve 0/20 | 34.0s
# Epoch  65/200 | lr 0.10000 | train 0.8230/85.76% | val raw/ema 85.26%/90.64% | test raw/ema 84.88%/90.43% | best_val 90.64% (ema) | no_improve 0/20 | 34.7s
# Epoch  66/200 | lr 0.10000 | train 0.8201/86.18% | val raw/ema 88.68%/90.80% | test raw/ema 88.16%/90.57% | best_val 90.80% (ema) | no_improve 0/20 | 34.7s
# Epoch  67/200 | lr 0.10000 | train 0.8230/85.78% | val raw/ema 87.76%/90.92% | test raw/ema 87.04%/90.77% | best_val 90.92% (ema) | no_improve 0/20 | 34.3s
# Epoch  68/200 | lr 0.10000 | train 0.8282/85.54% | val raw/ema 86.54%/91.16% | test raw/ema 87.44%/90.97% | best_val 91.16% (ema) | no_improve 0/20 | 35.8s
# Epoch  69/200 | lr 0.10000 | train 0.8254/85.97% | val raw/ema 82.08%/91.24% | test raw/ema 81.89%/91.08% | best_val 91.24% (ema) | no_improve 0/20 | 34.2s
# Epoch  70/200 | lr 0.10000 | train 0.8169/86.14% | val raw/ema 88.96%/91.32% | test raw/ema 88.83%/91.18% | best_val 91.32% (ema) | no_improve 0/20 | 35.5s
# Epoch  71/200 | lr 0.10000 | train 0.8237/85.84% | val raw/ema 86.60%/91.54% | test raw/ema 86.14%/91.27% | best_val 91.54% (ema) | no_improve 0/20 | 33.7s
# Epoch  72/200 | lr 0.10000 | train 0.8172/86.28% | val raw/ema 87.46%/91.76% | test raw/ema 87.20%/91.30% | best_val 91.76% (ema) | no_improve 0/20 | 34.5s
# Epoch  73/200 | lr 0.10000 | train 0.8221/86.00% | val raw/ema 87.86%/91.86% | test raw/ema 87.03%/91.39% | best_val 91.86% (ema) | no_improve 0/20 | 34.2s
# Epoch  74/200 | lr 0.10000 | train 0.8232/85.97% | val raw/ema 89.32%/91.96% | test raw/ema 88.83%/91.42% | best_val 91.96% (ema) | no_improve 0/20 | 33.7s
# Epoch  75/200 | lr 0.10000 | train 0.8165/86.22% | val raw/ema 88.00%/92.06% | test raw/ema 87.92%/91.53% | best_val 92.06% (ema) | no_improve 0/20 | 35.1s
# Epoch  76/200 | lr 0.10000 | train 0.8159/86.23% | val raw/ema 83.20%/92.04% | test raw/ema 82.22%/91.57% | best_val 92.06% (ema) | no_improve 1/20 | 32.9s
# Epoch  77/200 | lr 0.10000 | train 0.8129/86.43% | val raw/ema 88.36%/92.18% | test raw/ema 88.28%/91.65% | best_val 92.18% (ema) | no_improve 0/20 | 32.4s
# Epoch  78/200 | lr 0.10000 | train 0.8156/86.18% | val raw/ema 85.74%/92.22% | test raw/ema 85.58%/91.80% | best_val 92.18% (ema) | no_improve 1/20 | 34.3s
# Epoch  79/200 | lr 0.10000 | train 0.8162/86.29% | val raw/ema 87.58%/92.36% | test raw/ema 87.35%/91.85% | best_val 92.36% (ema) | no_improve 0/20 | 32.2s
# Epoch  80/200 | lr 0.10000 | train 0.8161/86.14% | val raw/ema 89.00%/92.50% | test raw/ema 87.16%/91.93% | best_val 92.50% (ema) | no_improve 0/20 | 33.3s
# Epoch  81/200 | lr 0.10000 | train 0.8125/86.29% | val raw/ema 88.58%/92.46% | test raw/ema 88.21%/91.98% | best_val 92.50% (ema) | no_improve 1/20 | 34.4s
# Epoch  82/200 | lr 0.10000 | train 0.8189/86.11% | val raw/ema 88.46%/92.62% | test raw/ema 88.01%/91.97% | best_val 92.62% (ema) | no_improve 0/20 | 32.0s
# Epoch  83/200 | lr 0.10000 | train 0.8180/86.05% | val raw/ema 89.30%/92.72% | test raw/ema 88.72%/92.06% | best_val 92.72% (ema) | no_improve 0/20 | 33.5s
# Epoch  84/200 | lr 0.10000 | train 0.8171/86.09% | val raw/ema 88.60%/92.70% | test raw/ema 88.20%/92.07% | best_val 92.72% (ema) | no_improve 1/20 | 34.9s
# Epoch  85/200 | lr 0.10000 | train 0.8111/86.28% | val raw/ema 86.88%/92.70% | test raw/ema 85.22%/92.09% | best_val 92.72% (ema) | no_improve 2/20 | 32.2s
# Epoch  86/200 | lr 0.10000 | train 0.8126/86.36% | val raw/ema 88.06%/92.90% | test raw/ema 88.29%/92.16% | best_val 92.90% (ema) | no_improve 0/20 | 32.3s
# Epoch  87/200 | lr 0.10000 | train 0.8150/86.29% | val raw/ema 87.84%/92.88% | test raw/ema 87.19%/92.20% | best_val 92.90% (ema) | no_improve 1/20 | 34.6s
# Epoch  88/200 | lr 0.10000 | train 0.8173/86.33% | val raw/ema 87.90%/92.92% | test raw/ema 87.80%/92.16% | best_val 92.90% (ema) | no_improve 2/20 | 32.5s
# Epoch  89/200 | lr 0.10000 | train 0.8116/86.32% | val raw/ema 88.42%/92.98% | test raw/ema 88.43%/92.25% | best_val 92.98% (ema) | no_improve 0/20 | 32.6s
# Epoch  90/200 | lr 0.10000 | train 0.8119/86.28% | val raw/ema 87.52%/93.10% | test raw/ema 87.41%/92.25% | best_val 93.10% (ema) | no_improve 0/20 | 35.0s
# Epoch  91/200 | lr 0.10000 | train 0.8098/86.31% | val raw/ema 86.72%/93.06% | test raw/ema 86.19%/92.22% | best_val 93.10% (ema) | no_improve 1/20 | 33.5s
# Epoch  92/200 | lr 0.10000 | train 0.8109/86.39% | val raw/ema 87.86%/93.16% | test raw/ema 87.28%/92.30% | best_val 93.16% (ema) | no_improve 0/20 | 33.6s
# Epoch  93/200 | lr 0.10000 | train 0.8157/86.27% | val raw/ema 89.36%/93.22% | test raw/ema 89.24%/92.31% | best_val 93.22% (ema) | no_improve 0/20 | 35.2s
# Epoch  94/200 | lr 0.10000 | train 0.8079/86.53% | val raw/ema 87.88%/93.32% | test raw/ema 87.25%/92.48% | best_val 93.32% (ema) | no_improve 0/20 | 33.8s
# Epoch  95/200 | lr 0.10000 | train 0.8126/86.14% | val raw/ema 88.86%/93.36% | test raw/ema 88.52%/92.57% | best_val 93.32% (ema) | no_improve 1/20 | 35.3s
# Epoch  96/200 | lr 0.10000 | train 0.8088/86.57% | val raw/ema 88.52%/93.30% | test raw/ema 88.07%/92.64% | best_val 93.32% (ema) | no_improve 2/20 | 32.5s
# Epoch  97/200 | lr 0.10000 | train 0.8116/86.29% | val raw/ema 88.28%/93.40% | test raw/ema 88.23%/92.70% | best_val 93.40% (ema) | no_improve 0/20 | 32.7s
# Epoch  98/200 | lr 0.10000 | train 0.8107/86.30% | val raw/ema 87.86%/93.36% | test raw/ema 87.68%/92.73% | best_val 93.40% (ema) | no_improve 1/20 | 34.6s
# Epoch  99/200 | lr 0.10000 | train 0.8133/86.44% | val raw/ema 89.28%/93.40% | test raw/ema 88.74%/92.67% | best_val 93.40% (ema) | no_improve 2/20 | 31.9s
# Epoch 100/200 | lr 0.10000 | train 0.8121/86.35% | val raw/ema 87.10%/93.48% | test raw/ema 85.82%/92.68% | best_val 93.48% (ema) | no_improve 0/20 | 32.4s
# Epoch 101/200 | lr 0.10000 | train 0.8082/86.35% | val raw/ema 87.56%/93.46% | test raw/ema 87.30%/92.73% | best_val 93.48% (ema) | no_improve 1/20 | 34.9s
# Epoch 102/200 | lr 0.10000 | train 0.8070/86.55% | val raw/ema 89.40%/93.56% | test raw/ema 89.10%/92.71% | best_val 93.56% (ema) | no_improve 0/20 | 32.6s
# Epoch 103/200 | lr 0.10000 | train 0.8110/86.42% | val raw/ema 87.88%/93.62% | test raw/ema 87.66%/92.77% | best_val 93.62% (ema) | no_improve 0/20 | 33.9s
# Epoch 104/200 | lr 0.10000 | train 0.8061/86.65% | val raw/ema 88.40%/93.48% | test raw/ema 88.06%/92.88% | best_val 93.62% (ema) | no_improve 1/20 | 34.9s
# Epoch 105/200 | lr 0.10000 | train 0.8095/86.48% | val raw/ema 88.80%/93.46% | test raw/ema 88.86%/92.98% | best_val 93.62% (ema) | no_improve 2/20 | 32.3s
# Epoch 106/200 | lr 0.10000 | train 0.8100/86.42% | val raw/ema 90.48%/93.50% | test raw/ema 89.41%/93.01% | best_val 93.62% (ema) | no_improve 3/20 | 32.5s
# Epoch 107/200 | lr 0.10000 | train 0.8051/86.68% | val raw/ema 88.44%/93.50% | test raw/ema 87.83%/93.11% | best_val 93.62% (ema) | no_improve 4/20 | 33.7s
# Epoch 108/200 | lr 0.10000 | train 0.8054/86.83% | val raw/ema 88.44%/93.48% | test raw/ema 88.20%/93.04% | best_val 93.62% (ema) | no_improve 5/20 | 32.5s
# Epoch 109/200 | lr 0.10000 | train 0.8086/86.58% | val raw/ema 87.92%/93.50% | test raw/ema 87.59%/93.09% | best_val 93.62% (ema) | no_improve 6/20 | 33.0s
# Epoch 110/200 | lr 0.10000 | train 0.8068/86.63% | val raw/ema 88.50%/93.42% | test raw/ema 88.16%/93.11% | best_val 93.62% (ema) | no_improve 7/20 | 33.7s
# Epoch 111/200 | lr 0.10000 | train 0.8053/86.70% | val raw/ema 90.06%/93.44% | test raw/ema 89.25%/93.09% | best_val 93.62% (ema) | no_improve 8/20 | 32.8s
# Epoch 112/200 | lr 0.05000 | train 0.8078/86.66% | val raw/ema 87.56%/93.40% | test raw/ema 87.55%/93.08% | best_val 93.62% (ema) | no_improve 9/20 | 33.4s
# Epoch 113/200 | lr 0.05000 | train 0.7301/89.89% | val raw/ema 91.94%/93.48% | test raw/ema 91.74%/93.18% | best_val 93.62% (ema) | no_improve 10/20 | 34.3s
# Epoch 114/200 | lr 0.05000 | train 0.7160/90.46% | val raw/ema 91.52%/93.66% | test raw/ema 91.15%/93.27% | best_val 93.62% (ema) | no_improve 11/20 | 32.8s
# Epoch 115/200 | lr 0.05000 | train 0.7140/90.65% | val raw/ema 92.24%/93.76% | test raw/ema 91.45%/93.33% | best_val 93.76% (ema) | no_improve 0/20 | 33.4s
# Epoch 116/200 | lr 0.05000 | train 0.7199/90.41% | val raw/ema 90.54%/93.78% | test raw/ema 90.29%/93.36% | best_val 93.76% (ema) | no_improve 1/20 | 35.0s
# Epoch 117/200 | lr 0.05000 | train 0.7176/90.44% | val raw/ema 91.26%/93.80% | test raw/ema 90.52%/93.41% | best_val 93.76% (ema) | no_improve 2/20 | 32.3s
# Epoch 118/200 | lr 0.05000 | train 0.7231/90.27% | val raw/ema 91.30%/93.90% | test raw/ema 90.42%/93.51% | best_val 93.90% (ema) | no_improve 0/20 | 32.8s
# Epoch 119/200 | lr 0.05000 | train 0.7201/90.38% | val raw/ema 90.36%/94.10% | test raw/ema 89.04%/93.56% | best_val 94.10% (ema) | no_improve 0/20 | 35.0s
# Epoch 120/200 | lr 0.05000 | train 0.7239/90.16% | val raw/ema 90.22%/94.20% | test raw/ema 90.20%/93.53% | best_val 94.20% (ema) | no_improve 0/20 | 33.7s
# Epoch 121/200 | lr 0.05000 | train 0.7253/90.13% | val raw/ema 91.62%/94.30% | test raw/ema 91.01%/93.63% | best_val 94.30% (ema) | no_improve 0/20 | 34.7s
# Epoch 122/200 | lr 0.05000 | train 0.7225/90.28% | val raw/ema 89.52%/94.34% | test raw/ema 89.72%/93.68% | best_val 94.30% (ema) | no_improve 1/20 | 34.2s
# Epoch 123/200 | lr 0.05000 | train 0.7263/90.02% | val raw/ema 91.14%/94.36% | test raw/ema 91.02%/93.72% | best_val 94.36% (ema) | no_improve 0/20 | 32.9s
# Epoch 124/200 | lr 0.05000 | train 0.7226/90.37% | val raw/ema 91.62%/94.44% | test raw/ema 90.74%/93.74% | best_val 94.44% (ema) | no_improve 0/20 | 35.0s
# Epoch 125/200 | lr 0.05000 | train 0.7199/90.28% | val raw/ema 91.50%/94.48% | test raw/ema 91.26%/93.78% | best_val 94.44% (ema) | no_improve 1/20 | 33.4s
# Epoch 126/200 | lr 0.05000 | train 0.7234/90.15% | val raw/ema 90.36%/94.50% | test raw/ema 89.64%/93.89% | best_val 94.50% (ema) | no_improve 0/20 | 32.7s
# Epoch 127/200 | lr 0.05000 | train 0.7217/90.28% | val raw/ema 91.08%/94.52% | test raw/ema 90.41%/93.90% | best_val 94.50% (ema) | no_improve 1/20 | 35.7s
# Epoch 128/200 | lr 0.05000 | train 0.7210/90.28% | val raw/ema 90.96%/94.52% | test raw/ema 90.12%/93.95% | best_val 94.50% (ema) | no_improve 2/20 | 33.3s
# Epoch 129/200 | lr 0.05000 | train 0.7224/90.25% | val raw/ema 91.54%/94.52% | test raw/ema 90.70%/93.96% | best_val 94.50% (ema) | no_improve 3/20 | 33.8s
# Epoch 130/200 | lr 0.05000 | train 0.7191/90.32% | val raw/ema 91.02%/94.56% | test raw/ema 90.69%/94.06% | best_val 94.56% (ema) | no_improve 0/20 | 33.6s
# Epoch 131/200 | lr 0.05000 | train 0.7213/90.30% | val raw/ema 91.14%/94.60% | test raw/ema 90.72%/94.17% | best_val 94.56% (ema) | no_improve 1/20 | 33.5s
# Epoch 132/200 | lr 0.05000 | train 0.7183/90.44% | val raw/ema 90.94%/94.66% | test raw/ema 90.84%/94.22% | best_val 94.66% (ema) | no_improve 0/20 | 33.6s
# Epoch 133/200 | lr 0.05000 | train 0.7140/90.71% | val raw/ema 91.04%/94.76% | test raw/ema 91.16%/94.32% | best_val 94.76% (ema) | no_improve 0/20 | 34.0s
# Epoch 134/200 | lr 0.05000 | train 0.7215/90.30% | val raw/ema 91.24%/94.84% | test raw/ema 90.87%/94.31% | best_val 94.84% (ema) | no_improve 0/20 | 34.2s
# Epoch 135/200 | lr 0.05000 | train 0.7200/90.34% | val raw/ema 90.82%/94.90% | test raw/ema 90.34%/94.46% | best_val 94.90% (ema) | no_improve 0/20 | 35.8s
# Epoch 136/200 | lr 0.05000 | train 0.7160/90.42% | val raw/ema 91.40%/94.98% | test raw/ema 90.40%/94.54% | best_val 94.98% (ema) | no_improve 0/20 | 34.8s
# Epoch 137/200 | lr 0.05000 | train 0.7209/90.20% | val raw/ema 90.86%/95.06% | test raw/ema 90.56%/94.59% | best_val 95.06% (ema) | no_improve 0/20 | 35.6s
# Epoch 138/200 | lr 0.05000 | train 0.7151/90.54% | val raw/ema 91.82%/95.10% | test raw/ema 91.11%/94.60% | best_val 95.06% (ema) | no_improve 1/20 | 34.5s
# Epoch 139/200 | lr 0.05000 | train 0.7209/90.28% | val raw/ema 90.36%/95.16% | test raw/ema 89.96%/94.69% | best_val 95.16% (ema) | no_improve 0/20 | 34.4s
# Epoch 140/200 | lr 0.05000 | train 0.7199/90.38% | val raw/ema 91.28%/95.10% | test raw/ema 90.37%/94.73% | best_val 95.16% (ema) | no_improve 1/20 | 34.8s
# Epoch 141/200 | lr 0.05000 | train 0.7164/90.63% | val raw/ema 91.40%/95.12% | test raw/ema 90.55%/94.74% | best_val 95.16% (ema) | no_improve 2/20 | 33.5s
# Epoch 142/200 | lr 0.05000 | train 0.7165/90.52% | val raw/ema 91.74%/95.12% | test raw/ema 91.74%/94.72% | best_val 95.16% (ema) | no_improve 3/20 | 34.5s
# Epoch 143/200 | lr 0.05000 | train 0.7166/90.45% | val raw/ema 90.76%/95.12% | test raw/ema 90.88%/94.70% | best_val 95.16% (ema) | no_improve 4/20 | 33.3s
# Epoch 144/200 | lr 0.05000 | train 0.7164/90.51% | val raw/ema 90.20%/95.08% | test raw/ema 90.14%/94.74% | best_val 95.16% (ema) | no_improve 5/20 | 33.5s
# Epoch 145/200 | lr 0.05000 | train 0.7161/90.41% | val raw/ema 91.70%/95.16% | test raw/ema 90.99%/94.77% | best_val 95.16% (ema) | no_improve 6/20 | 34.5s
# Epoch 146/200 | lr 0.05000 | train 0.7134/90.57% | val raw/ema 91.04%/95.12% | test raw/ema 90.44%/94.82% | best_val 95.16% (ema) | no_improve 7/20 | 33.2s
# Epoch 147/200 | lr 0.05000 | train 0.7131/90.70% | val raw/ema 91.40%/95.16% | test raw/ema 90.67%/94.82% | best_val 95.16% (ema) | no_improve 8/20 | 34.2s
# Epoch 148/200 | lr 0.05000 | train 0.7186/90.48% | val raw/ema 91.84%/95.22% | test raw/ema 91.55%/94.85% | best_val 95.22% (ema) | no_improve 0/20 | 33.8s
# Epoch 149/200 | lr 0.05000 | train 0.7128/90.68% | val raw/ema 91.56%/95.22% | test raw/ema 91.30%/94.84% | best_val 95.22% (ema) | no_improve 1/20 | 34.3s
# Epoch 150/200 | lr 0.05000 | train 0.7108/90.87% | val raw/ema 90.72%/95.28% | test raw/ema 90.65%/94.85% | best_val 95.28% (ema) | no_improve 0/20 | 34.8s
# Epoch 151/200 | lr 0.05000 | train 0.7139/90.62% | val raw/ema 92.28%/95.34% | test raw/ema 91.45%/94.83% | best_val 95.34% (ema) | no_improve 0/20 | 34.1s
# Epoch 152/200 | lr 0.05000 | train 0.7146/90.78% | val raw/ema 90.88%/95.40% | test raw/ema 90.38%/94.77% | best_val 95.40% (ema) | no_improve 0/20 | 35.3s
# Epoch 153/200 | lr 0.05000 | train 0.7143/90.53% | val raw/ema 91.76%/95.36% | test raw/ema 91.03%/94.78% | best_val 95.40% (ema) | no_improve 1/20 | 34.1s
# Epoch 154/200 | lr 0.05000 | train 0.7081/90.86% | val raw/ema 91.28%/95.42% | test raw/ema 90.96%/94.79% | best_val 95.40% (ema) | no_improve 2/20 | 33.1s
# Epoch 155/200 | lr 0.05000 | train 0.7173/90.47% | val raw/ema 91.48%/95.40% | test raw/ema 90.53%/94.79% | best_val 95.40% (ema) | no_improve 3/20 | 34.2s
# Epoch 156/200 | lr 0.05000 | train 0.7138/90.62% | val raw/ema 91.58%/95.36% | test raw/ema 91.14%/94.86% | best_val 95.40% (ema) | no_improve 4/20 | 32.7s
# Epoch 157/200 | lr 0.05000 | train 0.7151/90.50% | val raw/ema 88.96%/95.38% | test raw/ema 89.01%/94.87% | best_val 95.40% (ema) | no_improve 5/20 | 33.0s
# Epoch 158/200 | lr 0.05000 | train 0.7111/90.77% | val raw/ema 90.68%/95.40% | test raw/ema 90.19%/94.79% | best_val 95.40% (ema) | no_improve 6/20 | 34.6s
# Epoch 159/200 | lr 0.05000 | train 0.7139/90.60% | val raw/ema 91.00%/95.24% | test raw/ema 89.78%/94.76% | best_val 95.40% (ema) | no_improve 7/20 | 32.5s
# Epoch 160/200 | lr 0.05000 | train 0.7132/90.59% | val raw/ema 90.82%/95.22% | test raw/ema 90.11%/94.79% | best_val 95.40% (ema) | no_improve 8/20 | 33.6s
# Epoch 161/200 | lr 0.05000 | train 0.7075/90.91% | val raw/ema 91.18%/95.26% | test raw/ema 90.50%/94.79% | best_val 95.40% (ema) | no_improve 9/20 | 34.1s
# Epoch 162/200 | lr 0.05000 | train 0.7102/90.65% | val raw/ema 91.46%/95.28% | test raw/ema 90.99%/94.84% | best_val 95.40% (ema) | no_improve 10/20 | 33.8s
# Epoch 163/200 | lr 0.02500 | train 0.7124/90.74% | val raw/ema 91.72%/95.32% | test raw/ema 91.23%/94.80% | best_val 95.40% (ema) | no_improve 11/20 | 35.5s
# Epoch 164/200 | lr 0.02500 | train 0.6578/93.11% | val raw/ema 93.82%/95.40% | test raw/ema 93.44%/94.79% | best_val 95.40% (ema) | no_improve 12/20 | 33.2s
# Epoch 165/200 | lr 0.02500 | train 0.6392/93.93% | val raw/ema 93.66%/95.46% | test raw/ema 93.52%/94.90% | best_val 95.46% (ema) | no_improve 0/20 | 33.6s
# Epoch 166/200 | lr 0.02500 | train 0.6370/94.04% | val raw/ema 93.34%/95.50% | test raw/ema 93.43%/94.93% | best_val 95.46% (ema) | no_improve 1/20 | 35.5s
# Epoch 167/200 | lr 0.02500 | train 0.6353/94.09% | val raw/ema 93.28%/95.54% | test raw/ema 93.17%/95.01% | best_val 95.54% (ema) | no_improve 0/20 | 33.4s
# Epoch 168/200 | lr 0.02500 | train 0.6365/94.04% | val raw/ema 93.44%/95.62% | test raw/ema 93.01%/95.03% | best_val 95.62% (ema) | no_improve 0/20 | 36.7s
# Epoch 169/200 | lr 0.02500 | train 0.6364/94.08% | val raw/ema 93.72%/95.60% | test raw/ema 92.93%/95.13% | best_val 95.62% (ema) | no_improve 1/20 | 34.9s
# Epoch 170/200 | lr 0.02500 | train 0.6408/93.91% | val raw/ema 93.76%/95.66% | test raw/ema 93.56%/95.13% | best_val 95.62% (ema) | no_improve 2/20 | 34.5s
# Epoch 171/200 | lr 0.02500 | train 0.6411/93.78% | val raw/ema 93.56%/95.64% | test raw/ema 93.12%/95.13% | best_val 95.62% (ema) | no_improve 3/20 | 33.9s
# Epoch 172/200 | lr 0.02500 | train 0.6418/93.76% | val raw/ema 93.80%/95.72% | test raw/ema 92.99%/95.17% | best_val 95.72% (ema) | no_improve 0/20 | 33.3s
# Epoch 173/200 | lr 0.02500 | train 0.6387/93.98% | val raw/ema 93.74%/95.70% | test raw/ema 93.05%/95.23% | best_val 95.72% (ema) | no_improve 1/20 | 35.5s
# Epoch 174/200 | lr 0.02500 | train 0.6456/93.74% | val raw/ema 94.30%/95.76% | test raw/ema 93.20%/95.23% | best_val 95.72% (ema) | no_improve 2/20 | 33.4s
# Epoch 175/200 | lr 0.02500 | train 0.6447/93.67% | val raw/ema 93.46%/95.94% | test raw/ema 92.83%/95.28% | best_val 95.94% (ema) | no_improve 0/20 | 34.1s
# Epoch 176/200 | lr 0.02500 | train 0.6426/93.78% | val raw/ema 93.74%/95.94% | test raw/ema 93.06%/95.30% | best_val 95.94% (ema) | no_improve 1/20 | 35.8s
# Epoch 177/200 | lr 0.02500 | train 0.6418/93.76% | val raw/ema 93.28%/95.90% | test raw/ema 93.00%/95.26% | best_val 95.94% (ema) | no_improve 2/20 | 33.5s
# Epoch 178/200 | lr 0.02500 | train 0.6456/93.58% | val raw/ema 93.64%/96.00% | test raw/ema 92.76%/95.21% | best_val 96.00% (ema) | no_improve 0/20 | 35.3s
# Epoch 179/200 | lr 0.02500 | train 0.6437/93.65% | val raw/ema 93.64%/95.92% | test raw/ema 93.10%/95.22% | best_val 96.00% (ema) | no_improve 1/20 | 34.5s
# Epoch 180/200 | lr 0.02500 | train 0.6418/93.78% | val raw/ema 93.24%/95.94% | test raw/ema 93.04%/95.20% | best_val 96.00% (ema) | no_improve 2/20 | 33.6s
# Epoch 181/200 | lr 0.02500 | train 0.6463/93.76% | val raw/ema 93.58%/95.96% | test raw/ema 92.56%/95.20% | best_val 96.00% (ema) | no_improve 3/20 | 34.0s
# Epoch 182/200 | lr 0.02500 | train 0.6432/93.74% | val raw/ema 93.18%/96.02% | test raw/ema 93.33%/95.29% | best_val 96.00% (ema) | no_improve 4/20 | 33.4s
# Epoch 183/200 | lr 0.02500 | train 0.6477/93.51% | val raw/ema 92.80%/96.06% | test raw/ema 92.27%/95.33% | best_val 96.06% (ema) | no_improve 0/20 | 35.5s
# Epoch 184/200 | lr 0.02500 | train 0.6403/93.86% | val raw/ema 93.36%/96.08% | test raw/ema 92.78%/95.30% | best_val 96.06% (ema) | no_improve 1/20 | 34.7s
# Epoch 185/200 | lr 0.02500 | train 0.6450/93.63% | val raw/ema 93.68%/96.08% | test raw/ema 92.71%/95.30% | best_val 96.06% (ema) | no_improve 2/20 | 33.8s
# Epoch 186/200 | lr 0.02500 | train 0.6429/93.79% | val raw/ema 92.64%/96.06% | test raw/ema 91.94%/95.30% | best_val 96.06% (ema) | no_improve 3/20 | 34.5s
# Epoch 187/200 | lr 0.02500 | train 0.6457/93.62% | val raw/ema 93.96%/96.02% | test raw/ema 92.57%/95.34% | best_val 96.06% (ema) | no_improve 4/20 | 33.6s
# Epoch 188/200 | lr 0.02500 | train 0.6444/93.71% | val raw/ema 93.10%/96.00% | test raw/ema 92.73%/95.38% | best_val 96.06% (ema) | no_improve 5/20 | 35.0s
# Epoch 189/200 | lr 0.02500 | train 0.6441/93.63% | val raw/ema 93.52%/96.00% | test raw/ema 93.13%/95.41% | best_val 96.06% (ema) | no_improve 6/20 | 35.2s
# Epoch 190/200 | lr 0.02500 | train 0.6451/93.64% | val raw/ema 93.28%/95.94% | test raw/ema 91.87%/95.37% | best_val 96.06% (ema) | no_improve 7/20 | 34.9s
# Epoch 191/200 | lr 0.02500 | train 0.6461/93.56% | val raw/ema 93.98%/95.98% | test raw/ema 92.15%/95.39% | best_val 96.06% (ema) | no_improve 8/20 | 35.1s
# Epoch 192/200 | lr 0.02500 | train 0.6440/93.79% | val raw/ema 93.28%/96.02% | test raw/ema 92.82%/95.41% | best_val 96.06% (ema) | no_improve 9/20 | 34.0s
# Epoch 193/200 | lr 0.02500 | train 0.6504/93.39% | val raw/ema 93.40%/96.10% | test raw/ema 93.05%/95.49% | best_val 96.06% (ema) | no_improve 10/20 | 35.2s
# Epoch 194/200 | lr 0.02500 | train 0.6438/93.71% | val raw/ema 91.66%/96.08% | test raw/ema 91.57%/95.44% | best_val 96.06% (ema) | no_improve 11/20 | 33.5s
# Epoch 195/200 | lr 0.02500 | train 0.6422/93.77% | val raw/ema 92.98%/96.12% | test raw/ema 92.65%/95.55% | best_val 96.12% (ema) | no_improve 0/20 | 34.1s
# Epoch 196/200 | lr 0.02500 | train 0.6460/93.59% | val raw/ema 92.82%/96.16% | test raw/ema 92.39%/95.56% | best_val 96.12% (ema) | no_improve 1/20 | 36.5s
# Epoch 197/200 | lr 0.02500 | train 0.6393/93.93% | val raw/ema 92.98%/96.12% | test raw/ema 92.40%/95.58% | best_val 96.12% (ema) | no_improve 2/20 | 34.5s
# Epoch 198/200 | lr 0.02500 | train 0.6428/93.73% | val raw/ema 92.94%/96.12% | test raw/ema 92.73%/95.56% | best_val 96.12% (ema) | no_improve 3/20 | 36.7s
# Epoch 199/200 | lr 0.02500 | train 0.6483/93.49% | val raw/ema 92.68%/96.08% | test raw/ema 92.67%/95.51% | best_val 96.12% (ema) | no_improve 4/20 | 34.4s
# Epoch 200/200 | lr 0.02500 | train 0.6420/93.79% | val raw/ema 93.28%/96.08% | test raw/ema 92.75%/95.51% | best_val 96.12% (ema) | no_improve 5/20 | 35.5s
#
# Best checkpoint: epoch 195, source=ema, val_acc 96.12%
# Final test accuracy: 95.55%
# Honest clean train accuracy (same 45k images, no augmentation): 99.69%
# Honest train/test gap: 4.14 points
# Checkpoint saved to: /content/drive/MyDrive/atdl/resnet18_cifar10_fp32_baseline_best.pth

# %% [markdown]
# ## Training curves

# %%
actual_epochs = len(history["train_loss"])
epochs_range = range(1, actual_epochs + 1)
fig, axes = plt.subplots(2, 2, figsize=(12, 9))

axes[0, 0].plot(epochs_range, history["train_loss"], label="Train loss")
axes[0, 0].set_xlabel("Epoch"); axes[0, 0].set_ylabel("Loss")
axes[0, 0].set_title("Training Loss"); axes[0, 0].legend()

axes[0, 1].plot(epochs_range, history["train_acc"], label="Train (augmented)")
axes[0, 1].plot(epochs_range, history["val_acc_ema"], label="Val (EMA)")
axes[0, 1].plot(epochs_range, history["test_acc_ema"], label="Test (EMA)")
axes[0, 1].set_xlabel("Epoch"); axes[0, 1].set_ylabel("Accuracy (%)")
axes[0, 1].set_title("Accuracy"); axes[0, 1].legend()

gap = [tr - te for tr, te in zip(history["train_acc"], history["test_acc_ema"])]
axes[1, 0].plot(epochs_range, gap, color="darkred")
axes[1, 0].axhline(0, color="gray", linewidth=0.8, linestyle="--")
axes[1, 0].set_xlabel("Epoch"); axes[1, 0].set_ylabel("Train (augmented) - Test acc (points)")
axes[1, 0].set_title("Per-epoch gap (augmented train vs test -- see honest gap printed above)")

axes[1, 1].plot(epochs_range, history["lr"], color="darkgreen")
axes[1, 1].set_xlabel("Epoch"); axes[1, 1].set_ylabel("Learning rate")
axes[1, 1].set_title("LR schedule (warmup -> plateau decay)")
axes[1, 1].set_yscale("log")

plt.tight_layout()
plt.savefig(CURVE_PATH, dpi=150)
plt.show()
print(f"Saved training curves to {CURVE_PATH}")
# Out:
# Saved training curves to /content/drive/MyDrive/atdl/resnet18_baseline_training_curves.png
